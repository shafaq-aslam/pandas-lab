# %% [markdown]
# # date_range function

# %%
import pandas as pd

# %%
# generate daily dates in a given range
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'D')
# Out:
# DatetimeIndex(['2025-11-07', '2025-11-08', '2025-11-09', '2025-11-10',
#                '2025-11-11', '2025-11-12', '2025-11-13', '2025-11-14',
#                '2025-11-15', '2025-11-16', '2025-11-17', '2025-11-18',
#                '2025-11-19', '2025-11-20', '2025-11-21', '2025-11-22',
#                '2025-11-23', '2025-11-24', '2025-11-25', '2025-11-26',
#                '2025-11-27', '2025-11-28', '2025-11-29', '2025-11-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
# alternate days in a given range
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = '2D')
# Out:
# DatetimeIndex(['2025-11-07', '2025-11-09', '2025-11-11', '2025-11-13',
#                '2025-11-15', '2025-11-17', '2025-11-19', '2025-11-21',
#                '2025-11-23', '2025-11-25', '2025-11-27', '2025-11-29'],
#               dtype='datetime64[ns]', freq='2D')

# %%
# B -> business days
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'B')
# Out:
# DatetimeIndex(['2025-11-07', '2025-11-10', '2025-11-11', '2025-11-12',
#                '2025-11-13', '2025-11-14', '2025-11-17', '2025-11-18',
#                '2025-11-19', '2025-11-20', '2025-11-21', '2025-11-24',
#                '2025-11-25', '2025-11-26', '2025-11-27', '2025-11-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# W -> one week per day
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'W')
# Out:
# DatetimeIndex(['2025-11-09', '2025-11-16', '2025-11-23', '2025-11-30'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'W-SAT')
# Out:
# DatetimeIndex(['2025-11-08', '2025-11-15', '2025-11-22', '2025-11-29'], dtype='datetime64[ns]', freq='W-SAT')

# %%
# H -> Hourly data(factor)
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19808\3888401477.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'H')
# DatetimeIndex(['2025-11-07 00:00:00', '2025-11-07 01:00:00',
#                '2025-11-07 02:00:00', '2025-11-07 03:00:00',
#                '2025-11-07 04:00:00', '2025-11-07 05:00:00',
#                '2025-11-07 06:00:00', '2025-11-07 07:00:00',
#                '2025-11-07 08:00:00', '2025-11-07 09:00:00',
#                ...
#                '2025-11-29 15:00:00', '2025-11-29 16:00:00',
#                '2025-11-29 17:00:00', '2025-11-29 18:00:00',
#                '2025-11-29 19:00:00', '2025-11-29 20:00:00',
#                '2025-11-29 21:00:00', '2025-11-29 22:00:00',
#                '2025-11-29 23:00:00', '2025-11-30 00:00:00'],
#               dtype='datetime64[ns]', length=553, freq='h')

# %%
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = '6H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19808\1356082906.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = '6H')
# DatetimeIndex(['2025-11-07 00:00:00', '2025-11-07 06:00:00',
#                '2025-11-07 12:00:00', '2025-11-07 18:00:00',
#                '2025-11-08 00:00:00', '2025-11-08 06:00:00',
#                '2025-11-08 12:00:00', '2025-11-08 18:00:00',
#                '2025-11-09 00:00:00', '2025-11-09 06:00:00',
#                '2025-11-09 12:00:00', '2025-11-09 18:00:00',
#                '2025-11-10 00:00:00', '2025-11-10 06:00:00',
#                '2025-11-10 12:00:00', '2025-11-10 18:00:00',
#                '2025-11-11 00:00:00', '2025-11-11 06:00:00',
#                '2025-11-11 12:00:00', '2025-11-11 18:00:00',
#                '2025-11-12 00:00:00', '2025-11-12 06:00:00',
#                '2025-11-12 12:00:00', '2025-11-12 18:00:00',
# ...

# %%
# M -> Month end
pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'M')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19808\729071467.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start = '2025/11/7', end = '2025/11/30' ,freq = 'M')
# DatetimeIndex(['2025-11-30'], dtype='datetime64[ns]', freq='ME')

# %%
# MS -> Month start
pd.date_range(start = '2025/11/1', end = '2025/11/30' ,freq = 'MS')
# Out:
# DatetimeIndex(['2025-11-01'], dtype='datetime64[ns]', freq='MS')

# %%
# YE -> Year end (A is depricated)
pd.date_range(start = '2025/11/7', end = '2029/12/31' ,freq = 'YE')
# Out:
# DatetimeIndex(['2025-12-31', '2026-12-31', '2027-12-31', '2028-12-31',
#                '2029-12-31'],
#               dtype='datetime64[ns]', freq='YE-DEC')

# %%
# YS -> Year Start (A is depricated)
pd.date_range(start = '2025/11/7', end = '2029/12/31' ,freq = 'YS')
# Out:
# DatetimeIndex(['2026-01-01', '2027-01-01', '2028-01-01', '2029-01-01'], dtype='datetime64[ns]', freq='YS-JAN')

# %%
# using periods(number of results)
pd.date_range(start = '2025/11/7', periods = 25 ,freq = 'D')
# Out:
# DatetimeIndex(['2025-11-07', '2025-11-08', '2025-11-09', '2025-11-10',
#                '2025-11-11', '2025-11-12', '2025-11-13', '2025-11-14',
#                '2025-11-15', '2025-11-16', '2025-11-17', '2025-11-18',
#                '2025-11-19', '2025-11-20', '2025-11-21', '2025-11-22',
#                '2025-11-23', '2025-11-24', '2025-11-25', '2025-11-26',
#                '2025-11-27', '2025-11-28', '2025-11-29', '2025-11-30',
#                '2025-12-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '2025/11/7', periods = 25 ,freq = 'H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19808\683133068.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2025/11/7', periods = 25 ,freq = 'H')
# DatetimeIndex(['2025-11-07 00:00:00', '2025-11-07 01:00:00',
#                '2025-11-07 02:00:00', '2025-11-07 03:00:00',
#                '2025-11-07 04:00:00', '2025-11-07 05:00:00',
#                '2025-11-07 06:00:00', '2025-11-07 07:00:00',
#                '2025-11-07 08:00:00', '2025-11-07 09:00:00',
#                '2025-11-07 10:00:00', '2025-11-07 11:00:00',
#                '2025-11-07 12:00:00', '2025-11-07 13:00:00',
#                '2025-11-07 14:00:00', '2025-11-07 15:00:00',
#                '2025-11-07 16:00:00', '2025-11-07 17:00:00',
#                '2025-11-07 18:00:00', '2025-11-07 19:00:00',
#                '2025-11-07 20:00:00', '2025-11-07 21:00:00',
#                '2025-11-07 22:00:00', '2025-11-07 23:00:00',
# ...

# %%
pd.date_range(start = '2025/11/7', periods = 25 ,freq = '6H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19808\1826817051.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start = '2025/11/7', periods = 25 ,freq = '6H')
# DatetimeIndex(['2025-11-07 00:00:00', '2025-11-07 06:00:00',
#                '2025-11-07 12:00:00', '2025-11-07 18:00:00',
#                '2025-11-08 00:00:00', '2025-11-08 06:00:00',
#                '2025-11-08 12:00:00', '2025-11-08 18:00:00',
#                '2025-11-09 00:00:00', '2025-11-09 06:00:00',
#                '2025-11-09 12:00:00', '2025-11-09 18:00:00',
#                '2025-11-10 00:00:00', '2025-11-10 06:00:00',
#                '2025-11-10 12:00:00', '2025-11-10 18:00:00',
#                '2025-11-11 00:00:00', '2025-11-11 06:00:00',
#                '2025-11-11 12:00:00', '2025-11-11 18:00:00',
#                '2025-11-12 00:00:00', '2025-11-12 06:00:00',
#                '2025-11-12 12:00:00', '2025-11-12 18:00:00',
# ...

# %% [markdown]
# # to_datetime function

# %% [markdown]
# <p>Converts an existing objects to pandas timestamp/datetimeindex object.</p>

# %%
# simple series example
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/11/10'])
pd.to_datetime(series)
# Out:
# 0   2025-11-07
# 1   2025-11-08
# 2   2025-11-09
# 3   2025-11-10
# dtype: datetime64[ns]

# %%
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/11/10'])
pd.to_datetime(series).dt.year
# Out:
# 0    2025
# 1    2025
# 2    2025
# 3    2025
# dtype: int32

# %%
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/11/10'])
pd.to_datetime(series).dt.day
# Out:
# 0     7
# 1     8
# 2     9
# 3    10
# dtype: int32

# %%
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/11/10'])
pd.to_datetime(series).dt.day_name()
# Out:
# 0      Friday
# 1    Saturday
# 2      Sunday
# 3      Monday
# dtype: object

# %%
# with errors
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/131/10'])
pd.to_datetime(series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 # with errors
#       2 series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/131/10'])
# ----> 3 pd.to_datetime(series)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
# error handling
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/131/10'])
pd.to_datetime(series, errors = 'coerce')
# Out:
# 0   2025-11-07
# 1   2025-11-08
# 2   2025-11-09
# 3          NaT
# dtype: datetime64[ns]

# %%
series = pd.Series(['2025/11/7', '2025/11/8', '2025/11/9', '2025/131/10'])
pd.to_datetime(series, errors = 'coerce').dt.month_name()
# Out:
# 0    November
# 1    November
# 2    November
# 3         NaN
# dtype: object

# %% [markdown]
# ### Working with dataset

# %%
df = pd.read_csv('expense_data.csv')
df.shape
# Out:
# (277, 11)

# %%
df.sample(5)
# Out:
#                 Date               Account Category  Subcategory  \
# 212  12/9/2021 20:03  CUB - online payment     Food          NaN
# 136   1/5/2022 14:30  CUB - online payment     Food          NaN
# 125   1/6/2022 20:58  CUB - online payment     Food          NaN
# 139   1/4/2022 13:53  CUB - online payment     Food          NaN
# 131   1/5/2022 14:42  CUB - online payment    Other          NaN
#
#                                 Note    INR Income/Expense  Note.1  Amount  \
# 212               Snack with bharath   40.0        Expense     NaN    40.0
# 136               Lunch with company  388.0        Expense     NaN   388.0
# 125                         Ketch up   20.0        Expense     NaN    20.0
# 139               Lunch with company  106.0        Expense     NaN   106.0
# 131  Lended money returned to kumara   30.0        Expense     NaN    30.0
#
#     Currency  Account.1
# 212      INR       40.0
# 136      INR      388.0
# 125      INR       20.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %% [markdown]
# ## dt accessor

# %%
df['Date'].dt.is_quarter_start
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
df['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
df['Date'].dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
df['Date'].dt.is_month_end
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# Name: Date, Length: 277, dtype: bool

# %%
df['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
df['Date'].dt.day_name()
# Out:
# 0      Wednesday
# 1      Wednesday
# 2        Tuesday
# 3        Tuesday
# 4        Tuesday
#          ...
# 272       Monday
# 273       Monday
# 274       Sunday
# 275       Sunday
# 276       Sunday
# Name: Date, Length: 277, dtype: object

# %% [markdown]
# ## Plot graph

# %%
import matplotlib.pyplot as plt
plt.plot(df['Date'], df['INR'])

# %%
# day name wise bar chart/month wise bar chart
df['day_name'] = df['Date'].dt.day_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#     day_name
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('day_name')['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
df['month_name'] = df['Date'].dt.month_name()

# %%
df.groupby('month_name')['INR'].sum().plot(kind = 'pie')
# Out:
# <Axes: ylabel='INR'>
