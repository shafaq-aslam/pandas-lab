# %% [markdown]
# # Time and Date

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Timestamp Object

# %% [markdown]
# <p>Time stamps reference particular moments in time (e.g., Oct 24th, 2022 at 7:00pm)</p>

# %% [markdown]
# ## Creating Timestamp Objects

# %%
# Creating a timestamp
pd.Timestamp('2025/11/7')
# Out:
# Timestamp('2025-11-07 00:00:00')

# %%
# variations
pd.Timestamp('2025-11-7')
# Out:
# Timestamp('2025-11-07 00:00:00')

# %%
pd.Timestamp('2025, 11, 7')
# Out:
# Timestamp('2025-11-07 00:00:00')

# %%
# only year
pd.Timestamp('2025')
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
# using text
pd.Timestamp('7th November 2025')
# Out:
# Timestamp('2025-11-07 00:00:00')

# %%
# provide time also
pd.Timestamp('7th November 2025 9:55AM')
# Out:
# Timestamp('2025-11-07 09:55:00')

# %%
pd.Timestamp('2025/11/7 9:55AM')
# Out:
# Timestamp('2025-11-07 09:55:00')

# %%
pd.Timestamp('2025-11-7 9:55AM')
pd.Timestamp('2025, 11, 7 9:55AM')
# Out:
# Timestamp('2025-11-07 09:55:00')

# %%
# using datetime.datetime object
import datetime as dt
time_date = pd.Timestamp(dt.datetime(2023, 1, 5, 9, 21, 56))
time_date
# Out:
# Timestamp('2023-01-05 09:21:56')

# %%
# fetching attributes
time_date.year
time_date.month
# Out:
# 1
