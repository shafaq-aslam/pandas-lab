# %% [markdown]
# # Practice Questions

# %%
import numpy as np , pandas as pd

# %%
courses = pd.read_csv('courses.csv')
students = pd.read_csv('students.csv')
reg_month1 = pd.read_csv('reg-month1.csv')
reg_month2 = pd.read_csv('reg-month2.csv')
matches = pd.read_csv('matches.csv')
deliveries = pd.read_csv('deliveries.csv')

# %%
registrations = pd.concat([reg_month1, reg_month2], ignore_index = True)

# %%
# 1. find total revenue generated by the company
total_revenue = registrations.merge(courses, how = 'inner', on = 'course_id')['price'].sum()
total_revenue
# Out:
# np.int64(154247)

# %%
# 2. find month by month revenue
temp_df = pd.concat([reg_month1, reg_month2], keys = ['Nov', 'Dec']).reset_index()
new_temp_df = temp_df.merge(courses, on = 'course_id')
new_temp_df.groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
# 3. Print the registration table

# %%
# 4. Plot bar chart for revenue/course

# %%
# 5. find students who enrolled in both the months

# %%
# 6. find course that got no enrollment

# %%
# 7. find students who did not enroll into any courses

# %%
# 8. Print student name -- partner name for all enrolled students

# %%
# 9. find top 3 students who did most number enrollments

# %%
# 10. find top 3 students who spent most amount of money on courses
